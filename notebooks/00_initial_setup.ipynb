# %%
import sys
from pathlib import Path

# Add project root to Python path
project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

import pandas as pd
from scripts.download_datasets import download_and_extract
import numpy as np
import matplotlib.pyplot as plt

# %%
hdfs_url = "https://zenodo.org/records/8196385/files/HDFS_v1.zip"
download_and_extract(hdfs_url, data_dir='../data/hdfs')
# Out:
# Downloading HDFS_v1.zip...
# Progress: 100.0%
# ✓ Downloaded to data/hdfs/HDFS_v1.zip
# Extracting ZIP archive...
# ✓ Extracted to data/hdfs/
# 'data/hdfs/HDFS_v1.zip'

# %%
bgl_url = "https://zenodo.org/records/8196385/files/BGL.zip"
download_and_extract(bgl_url, data_dir='../data/bgl')
# Out:
# Downloading https://zenodo.org/records/8196385/files/BGL.zip...
# Progress: 100.0%
# ✓ Downloaded to ../data/bgl/BGL.zip
# Extracting ZIP archive...
# ✓ Extracted to ../data/bgl/
# '../data/bgl/BGL.zip'
